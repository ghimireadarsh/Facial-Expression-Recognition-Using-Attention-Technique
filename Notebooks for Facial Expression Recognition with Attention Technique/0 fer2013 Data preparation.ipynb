# %% [markdown]
# ## [FER2013](https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/data) data preparation
#
# CSV file downloaded from Kaggle are processed and saved to different folders depending on Training, PublicTest, and PrivateTest folders categories.
#
# Each folders has all the categories like (Angry, Sad, Fear, Surprise, Happy, Neutral, Disgust).
#
# Training, Validation and Test folder are zipped and stored in google drive
#
# This notebook prepares data to be readily useful in Colab for later use.

# %%
# Connecting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Checking the current directory contents
# !ls
# Out:
# drive  sample_data

# %%
# Checking the present working directory path
# !pwd
# Out:
# /content

# %%
# Reading the downloaded CSV file using numpy
import os
import numpy as np

"""
    0 = Angry, 
    1 = Disgust, 
    2 = Fear, 
    3 = Happy,
    4 = Sad,
    5 = Surprise,
    6 = Neutral
"""
label_dictionary = {
    0 : "Angry",
    1 : "Disgust",
    2 : "Fear", 
    3 : "Happy",
    4 : "Sad",
    5 : "Surprise",
    6 : "Neutral"
}
label_names = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# dataset path og google drive
dataset_path = "/content/drive/My Drive/ENGR635-Deep Learning System Design Project/Dataset/fer2013/fer2013.csv" 
data = np.genfromtxt(dataset_path, delimiter=',',dtype=None, encoding='utf8')
print(data.shape)
# Out:
# (35888, 3)

# %%
# Header
data[0]
# Out:
# array(['emotion', 'pixels', 'Usage'], dtype='<U9215')

# %%
# first sample data
data[1]
# Out:
# array(['0',
#        '70 80 82 72 58 58 60 63 54 58 60 48 89 115 121 119 115 110 98 91 84 84 90 99 110 126 143 153 158 171 169 172 169 165 129 110 113 107 95 79 66 62 56 57 61 52 43 41 65 61 58 57 56 69 75 70 65 56 54 105 146 154 151 151 155 155 150 147 147 148 152 158 164 172 177 182 186 189 188 190 188 180 167 116 95 103 97 77 72 62 55 58 54 56 52 44 50 43 54 64 63 71 68 64 52 66 119 156 161 164 163 164 167 168 170 174 175 176 178 179 183 187 190 195 197 198 197 198 195 191 190 145 86 100 90 65 57 60 54 51 41 49 56 47 38 44 63 55 46 52 54 55 83 138 157 158 165 168 172 171 173 176 179 179 180 182 185 187 189 189 192 197 200 199 196 198 200 198 197 177 91 87 96 58 58 59 51 42 37 41 47 45 37 35 36 30 41 47 59 94 141 159 161 161 164 170 171 172 176 178 179 182 183 183 187 189 192 192 194 195 200 200 199 199 200 201 197 193 111 71 108 69 55 61 51 42 43 56 54 44 24 29 31 45 61 72 100 136 150 159 163 162 163 170 172 171 174 177 177 180 187 186 187 189 192 192 194 195 196 197 199 200 201 200 197 201 137 58 98 92 57 62 53 47 41 40 51 43 24 35 52 63 75 104 129 143 149 158 162 164 166 171 173 172 174 178 178 179 187 188 188 191 193 194 195 198 199 199 197 198 197 197 197 201 164 52 78 87 69 58 56 50 54 39 44 42 26 31 49 65 91 119 134 145 147 152 159 163 167 171 170 169 174 178 178 179 187 187 185 187 190 188 187 191 197 201 199 199 200 197 196 197 182 58 62 77 61 60 55 49 59 52 54 44 22 30 47 68 102 123 136 144 148 150 153 157 167 172 173 170 171 177 179 178 186 190 186 189 196 193 191 194 190 190 192 197 201 203 199 194 189 69 48 74 56 60 57 50 59 59 51 41 20 34 47 79 111 132 139 143 145 147 150 151 160 169 172 171 167 171 177 177 174 180 182 181 192 196 189 192 198 195 194 196 198 201 202 195 189 70 39 69 61 61 61 53 59 59 45 40 26 40 61 93 124 135 138 142 144 146 151 152 158 165 168 168 165 161 164 173 172 167 172 167 180 198 198 193 199 195 194 198 200 198 197 195 190 65 35 68 59 59 62 57 60 59 50 44 32 54 90 115 132 137 138 140 144 146 146 156 165 168 174 176 176 175 168 168 169 171 175 171 172 192 194 184 198 205 201 194 195 193 195 192 186 57 38 72 65 57 62 58 57 60 54 49 47 79 116 130 138 141 141 139 141 143 145 157 164 164 166 173 174 176 179 179 176 181 189 188 173 180 175 160 182 189 198 192 189 190 190 188 172 46 44 64 66 59 62 57 56 62 53 50 66 103 133 137 141 143 141 136 132 131 136 127 118 111 107 108 123 131 143 154 158 166 177 181 175 170 159 148 171 161 176 185 192 194 188 190 162 53 49 58 63 61 61 55 56 61 51 50 81 116 139 142 142 146 144 136 128 119 112 97 85 90 91 88 92 90 80 81 84 106 122 132 144 145 144 147 163 147 163 173 181 190 187 191 167 61 48 53 61 61 58 54 56 61 51 53 89 123 140 144 145 146 147 136 122 107 99 95 92 90 87 83 76 67 52 46 52 63 69 83 96 119 132 148 159 136 137 143 138 143 152 156 156 70 48 50 59 61 57 54 54 61 52 56 93 124 135 140 144 148 150 140 125 114 101 80 54 56 54 41 41 33 40 39 35 49 60 63 74 107 129 147 147 116 111 100 77 76 86 108 111 73 49 50 60 62 60 57 55 63 59 56 89 121 134 139 146 151 152 150 141 127 111 96 77 85 70 32 31 37 91 65 50 48 59 73 83 112 136 155 130 60 46 38 40 43 81 116 91 72 52 48 58 62 62 59 53 61 59 52 85 114 134 140 147 154 159 158 153 145 143 150 126 121 125 68 45 89 137 95 70 78 75 95 109 131 153 171 94 23 16 32 82 82 65 113 77 71 54 48 56 62 62 60 53 60 56 52 75 108 133 141 149 158 166 169 167 163 156 155 146 112 119 134 127 142 140 121 117 129 114 120 129 146 174 191 98 46 33 33 109 147 98 109 67 73 55 50 56 64 64 61 58 61 53 54 64 106 129 140 148 159 169 175 176 174 165 159 156 145 120 115 124 127 131 133 141 147 142 141 147 161 182 202 154 114 96 100 158 158 153 123 61 76 57 48 56 64 64 63 62 61 54 55 44 97 131 137 147 158 168 177 181 183 179 170 168 169 165 155 152 151 152 154 162 165 158 153 158 168 187 206 186 147 135 144 145 152 178 115 57 74 58 48 58 64 63 63 59 63 55 53 66 104 130 132 144 153 162 170 180 185 187 181 178 182 180 177 173 171 171 177 176 172 164 161 167 164 185 207 197 173 152 141 141 161 191 104 54 69 60 48 57 65 62 60 57 64 55 50 94 111 124 130 135 ...
#        'Training'], dtype='<U9215')

# %% [markdown]
# ### Working on labels

# %%
labels = data[1:,0].astype(np.int8) # Converting the labels to numpy integer, because originally it was on string format

# %%
labels
# Out:
# array([0, 0, 2, ..., 0, 3, 2], dtype=int8)

# %%
np.unique(labels, return_counts=True) # Checking the number of counts in each categories
# Out:
# (array([0, 1, 2, 3, 4, 5, 6], dtype=int8),
#  array([4953,  547, 5121, 8989, 6077, 4002, 6198]))

# %%
# Mapping the integer labels to actual labels
key, values = np.unique(labels, return_counts=True)
for i in key:
  print(label_dictionary[i], values[i])
# Out:
# Angry 4953
# Disgust 547
# Fear 5121
# Happy 8989
# Sad 6077
# Surprise 4002
# Neutral 6198

# %% [markdown]
# ### Working on image data

# %%
from keras.preprocessing.image import img_to_array, array_to_img

# %%
images = data[1:,1] # Except header (1:) --> Images pixel lies on second column(1).

# %%
# Converting all the strings form of pixels into array
images = np.array([np.fromstring(image, np.uint8, sep=' ') for image in images])

# %%
usage = data[1:, 2]
dataset = zip(labels, images, usage)

# %%
np.unique(usage, return_counts=True) # Checking the number of data in training, publictest and privatetest dataset
# Out:
# (array(['PrivateTest', 'PublicTest', 'Training'], dtype='<U9215'),
#  array([ 3589,  3589, 28709]))

# %%
# !ls "/content/drive/My Drive/ENGR635-Deep Learning System Design Project/Dataset/fer2013/"
# Out:
# fer2013.csv

# %%
# This code block takes all the numpy array containing pixel information,
# converts to images, saves to respective categories of emotion, which are further 
# saved to Training, PublicTest, and PrivateTest folders
for i, d in enumerate(dataset):
    usage_path = os.path.join(d[-1],"")
    label_path = os.path.join(usage_path, label_names[d[0]])
    img = array_to_img(d[1].reshape((48, 48, 1)))
    img_name = '%d.png' % i
    img_path = os.path.join(label_path, img_name)
    if not os.path.exists(usage_path):
        os.mkdir(usage_path)
    if not os.path.exists(label_path):
        os.mkdir(label_path)
    img.save(img_path)
print("Completed !!!")
# Out:
# Completed !!!

# %%
# !ls # Checking current directory contents
# Out:
# drive  PrivateTest  PublicTest	sample_data  Training

# %%
# Checking the number of images counts in Training directory
# %%bash
root='Training/'
IFS=$(echo -en "\n\b")
(for dir in $(ls -1 "$root")
    do printf "$dir: " && ls -i "$root$dir" | wc -l
 done)
# Out:
# Angry: 3995
# Disgust: 436
# Fear: 4097
# Happy: 7215
# Neutral: 4965
# Sad: 4830
# Surprise: 3171

# %%
# Checking the number of images counts in PublicTest directory
# %%bash
root='PublicTest/'
IFS=$(echo -en "\n\b")
(for dir in $(ls -1 "$root")
    do printf "$dir: " && ls -i "$root$dir" | wc -l
 done)
# Out:
# Angry: 467
# Disgust: 56
# Fear: 496
# Happy: 895
# Neutral: 607
# Sad: 653
# Surprise: 415

# %%
# Checking the number of images counts in PrivateTest directory
# %%bash
root='PrivateTest/'
IFS=$(echo -en "\n\b")
(for dir in $(ls -1 "$root")
    do printf "$dir: " && ls -i "$root$dir" | wc -l
 done)
# Out:
# Angry: 491
# Disgust: 55
# Fear: 528
# Happy: 879
# Neutral: 626
# Sad: 594
# Surprise: 416

# %%
# Zipping all the folders for saving it in drive
# %%bash
(for dir in Training PublicTest PrivateTest
    do pushd $dir && zip -r $dir.zip * && popd
 done)
# Out:
# /content/Training /content
#   adding: Angry/ (stored 0%)
#   adding: Angry/19458.png (stored 0%)
#   adding: Angry/18602.png (stored 0%)
#   adding: Angry/21271.png (stored 0%)
#   adding: Angry/2394.png (stored 0%)
#   adding: Angry/14315.png (stored 0%)
#   adding: Angry/16741.png (stored 0%)
#   adding: Angry/8202.png (stored 0%)
#   adding: Angry/8092.png (stored 0%)
#   adding: Angry/13402.png (deflated 10%)
#   adding: Angry/5295.png (stored 0%)
#   adding: Angry/18889.png (stored 0%)
#   adding: Angry/18022.png (stored 0%)
#   adding: Angry/2108.png (stored 0%)
#   adding: Angry/16761.png (stored 0%)
#   adding: Angry/18001.png (stored 0%)
#   adding: Angry/22647.png (stored 0%)
#   adding: Angry/4229.png (stored 0%)
#   adding: Angry/12237.png (stored 0%)
#   adding: Angry/24902.png (stored 0%)
#   adding: Angry/3564.png (stored 0%)
#   adding: Angry/23793.png (stored 0%)
#   adding: Angry/11158.png (stored 0%)
#   adding: Angry/12543.png (stored 0%)
#   adding: Angry/16657.png (stored 0%)
#   adding: Angry/18343.png (stored 0%)
#   adding: Angry/4317.png (stored 0%)
#   adding: Angry/19170.png (stored 0%)
#   adding: Angry/3387.png (stored 0%)
#   adding: Angry/21512.png (stored 0%)
#   adding: Angry/15344.png (stored 0%)
#   adding: Angry/3605.png (stored 0%)
#   adding: Angry/19115.png (stored 0%)
#   adding: Angry/3520.png (stored 0%)
#   adding: Angry/21163.png (stored 0%)
#   adding: Angry/0.png (stored 0%)
#   adding: Angry/18432.png (stored 0%)
#   adding: Angry/24638.png (stored 0%)
#   adding: Angry/25883.png (stored 0%)
#   adding: Angry/5848.png (stored 0%)
#   adding: Angry/6584.png (stored 0%)
#   adding: Angry/6629.png (stored 0%)
#   adding: Angry/24847.png (stored 0%)
#   adding: Angry/21064.png (stored 0%)
#   adding: Angry/15825.png (stored 0%)
#   adding: Angry/4503.png (stored 0%)
#   adding: Angry/1160.png (stored 0%)
#   adding: Angry/23459.png (stored 0%)
#   adding: Angry/14215.png (stored 0%)
#   adding: Angry/24453.png (stored 0%)
#   adding: Angry/23986.png (stored 0%)
#   adding: Angry/27930.png (stored 0%)
#   adding: Angry/28560.png (stored 0%)
#   adding: Angry/6738.png (stored 0%)
#   adding: Angry/18887.png (stored 0%)
#   adding: Angry/14482.png (stored 0%)
#   adding: Angry/27904.png (stored 0%)
#   adding: Angry/4239.png (stored 0%)
#   adding: Angry/3668.png (stored 0%)
#   adding: Angry/636.png (stored 0%)
#   adding: Angry/4475.png (stored 0%)
#   adding: Angry/26185.png (stored 0%)
#   adding: Angry/1123.png (stored 0%)
#   adding: Angry/12595.png (stored 0%)
#   adding: Angry/1595.png (stored 0%)
#   adding: Angry/3208.png (stored 0%)
#   adding: Angry/15273.png (stored 0%)
#   adding: Angry/13770.png (stored 0%)
#   adding: Angry/9752.png (stored 0%)
#   adding: Angry/18048.png (stored 0%)
#   adding: Angry/2288.png (stored 0%)
#   adding: Angry/8550.png (stored 0%)
#   adding: Angry/4656.png (stored 0%)
#   adding: Angry/1924.png (stored 0%)
#   adding: Angry/431.png (stored 0%)
#   adding: Angry/12025.png (stored 0%)
#   adding: Angry/11825.png (stored 0%)
#   adding: Angry/4054.png (stored 0%)
#   adding: Angry/14599.png (stored 0%)
#   adding: Angry/5545.png (stored 0%)
#   adding: Angry/16414.png (stored 0%)
#   adding: Angry/1444.png (stored 0%)
#   adding: Angry/19802.png (stored 0%)
#   adding: Angry/7377.png (stored 0%)
#   adding: Angry/14058.png (stored 0%)
#   adding: Angry/28481.png (stored 0%)
#   adding: Angry/10563.png (stored 0%)
#   adding: Angry/19311.png (stored 0%)
#   adding: Angry/3787.png (stored 0%)
#   adding: Angry/18720.png (stored 0%)
#   adding: Angry/2111.png (stored 0%)
#   adding: Angry/1672.png (stored 0%)
#   adding: Angry/9423.png (stored 0%)
#   adding: Angry/16014.png (stored 0%)
#   adding: Angry/8255.png (stored 0%)
#   adding: Angry/19448.png (stored 0%)
#   adding: Angry/23382.png (stored 0%)
#   adding: Angry/26302.png (stored 0%)
#   adding: Angry/1490.png (stored 0%)
#   adding: Angry/26699.png (stored 0%)
#   adding: Angry/21295.png (stored 0%)
#   adding: Angry/8900.png (stored 0%)
#   adding: Angry/404.png (stored 0%)
#   adding: Angry/24490.png (stored 0%)
#   adding: Angry/4336.png (stored 0%)
#   adding: Angry/27897.png (stored 0%)
#   adding: Angry/9677.png (stored 0%)
#   adding: Angry/4637.png (stored 0%)
#   adding: Angry/19811.png (stored 0%)
#   adding: Angry/15139.png (stored 0%)
#   adding: Angry/7818.png (stored 0%)
#   adding: Angry/7656.png (stored 0%)
#   adding: Angry/16073.png (stored 0%)
#   adding: Angry/8402.png (stored 0%)
#   adding: Angry/16137.png (stored 0%)
#   adding: Angry/16884.png (stored 0%)
#   adding: Angry/20956.png (stored 0%)
#   adding: Angry/19485.png (stored 0%)
#   adding: Angry/14148.png (stored 0%)
#   adding: Angry/23416.png (stored 0%)
#   adding: Angry/15700.png (stored 0%)
#   adding: Angry/27109.png (stored 0%)
#   adding: Angry/16653.png (stored 0%)
#   adding: Angry/519.png (stored 0%)
#   adding: Angry/16468.png (stored 0%)
#   adding: Angry/17813.png (stored 0%)
#   adding: Angry/23177.png (stored 0%)
#   adding: Angry/12810.png (stored 0%)
#   adding: Angry/19173.png (stored 0%)
#   adding: Angry/20273.png (stored 0%)
#   adding: Angry/25787.png (stored 0%)
#   adding: Angry/23771.png (stored 0%)
#   adding: Angry/6812.png (stored 0%)
#   adding: Angry/7552.png (stored 0%)
#   adding: Angry/2150.png (stored 0%)
#   adding: Angry/27149.png (stored 0%)
#   adding: Angry/7999.png (stored 0%)
#   adding: Angry/2067.png (stored 0%)
#   adding: Angry/2665.png (stored 0%)
#   adding: Angry/4324.png (stored 0%)
#   adding: Angry/28026.png (stored 0%)
#   adding: Angry/2315.png (stored 0%)
#   adding: Angry/3911.png (stored 0%)
#   adding: Angry/3808.png (stored 0%)
#   adding: Angry/12196.png (stored 0%)
#   adding: Angry/24020.png (stored 0%)
#   adding: Angry/4905.png (stored 0%)
#   adding: Angry/23571.png (stored 0%)
#   adding: Angry/12294.png (stored 0%)
#   adding: Angry/10771.png (stored 0%)
#   adding: Angry/19954.png (stored 0%)
#   adding: Angry/2818.png (stored 0%)
#   adding: Angry/18112.png (stored 0%)
#   adding: Angry/19638.png (stored 0%)
#   adding: Angry/3226.png (stored 0%)
#   adding: Angry/4934.png (stored 0%)
#   adding: Angry/12645.png (stored 0%)
#   adding: Angry/25549.png (stored 0%)
#   adding: Angry/11083.png (stored 0%)
#   adding: Angry/18384.png (stored 0%)
#   adding: Angry/8432.png (stored 0%)
#   adding: Angry/2486.png (stored 0%)
#   adding: Angry/8010.png (stored 0%)
#   adding: Angry/5496.png (stored 0%)
#   adding: Angry/18176.png (stored 0%)
#   adding: Angry/17527.png (stored 0%)
#   adding: Angry/12222.png (stored 0%)
#   adding: Angry/9234.png (stored 0%)
#   adding: Angry/15005.png (stored 0%)
#   adding: Angry/17140.png (stored 0%)
#   adding: Angry/7545.png (stored 0%)
#   adding: Angry/1825.png (stored 0%)
#   adding: Angry/25269.png (stored 0%)
#   adding: Angry/5512.png (stored 0%)
#   adding: Angry/13220.png (stored 0%)
#   adding: Angry/11557.png (stored 0%)
#   adding: Angry/20625.png (stored 0%)
#   adding: Angry/17009.png (stored 0%)
#   adding: Angry/22375.png (stored 0%)
#   adding: Angry/27483.png (stored 0%)
#   adding: Angry/5519.png (stored 0%)
#   adding: Angry/26669.png (stored 0%)
#   adding: Angry/14937.png (stored 0%)
#   adding: Angry/25791.png (stored 0%)
#   adding: Angry/881.png (stored 0%)
#   adding: Angry/1252.png (stored 0%)
#   adding: Angry/26331.png (stored 0%)
#   adding: Angry/18293.png (stored 0%)
#   adding: Angry/7136.png (stored 0%)
#   adding: Angry/3102.png (stored 0%)
#   adding: Angry/8930.png (stored 0%)
#   adding: Angry/17591.png (stored 0%)
#   adding: Angry/24383.png (stored 0%)
#   adding: Angry/16287.png (stored 0%)
#   adding: Angry/26988.png (stored 0%)
#   adding: Angry/4065.png (stored 0%)
#   adding: Angry/9988.png (stored 0%)
#   adding: Angry/13672.png (stored 0%)
#   adding: Angry/6765.png (stored 0%)
#   adding: Angry/27740.png (stored 0%)
#   adding: Angry/20404.png (stored 0%)
#   adding: Angry/18588.png (stored 0%)
#   adding: Angry/22184.png (stored 0%)
#   adding: Angry/203.png (stored 0%)
#   adding: Angry/4232.png (stored 0%)
#   adding: Angry/23361.png (stored 0%)
#   adding: Angry/12770.png (stored 0%)
#   adding: Angry/24325.png (stored 0%)
#   adding: Angry/23008.png (stored 0%)
#   adding: Angry/14312.png (stored 0%)
#   adding: Angry/9505.png (stored 0%)
#   adding: Angry/14575.png (stored 0%)
#   adding: Angry/26958.png (stored 0%)
#   adding: Angry/16494.png (stored 0%)
#   adding: Angry/24152.png (stored 0%)
#   adding: Angry/7581.png (stored 0%)
#   adding: Angry/7778.png (stored 0%)
#   adding: Angry/23041.png (stored 0%)
#   adding: Angry/6232.png (stored 0%)
#   adding: Angry/19236.png (stored 0%)
#   adding: Angry/11949.png (stored 0%)
#   adding: Angry/23773.png (stored 0%)
#   adding: Angry/17000.png (stored 0%)
#   adding: Angry/23157.png (stored 0%)
#   adding: Angry/27272.png (stored 0%)
#   adding: Angry/14669.png (stored 0%)
#   adding: Angry/2712.png (stored 0%)
#   adding: Angry/850.png (stored 0%)
#   adding: Angry/1736.png (stored 0%)
#   adding: Angry/20071.png (stored 0%)
#   adding: Angry/25876.png (stored 0%)
#   adding: Angry/1957.png (stored 0%)
#   adding: Angry/13425.png (stored 0%)
#   adding: Angry/1392.png (stored 0%)
#   adding: Angry/21567.png (stored 0%)
#   adding: Angry/18806.png (stored 0%)
#   adding: Angry/19961.png (stored 0%)
#   adding: Angry/14085.png (stored 0%)
#   adding: Angry/10377.png (stored 0%)
#   adding: Angry/9815.png (stored 0%)
#   adding: Angry/20297.png (stored 0%)
#   adding: Angry/6929.png (stored 0%)
#   adding: Angry/13442.png (stored 0%)
#   adding: Angry/2891.png (stored 0%)
#   adding: Angry/19304.png (stored 0%)
#   adding: Angry/17823.png (stored 0%)
#   adding: Angry/28541.png (stored 0%)
#   adding: Angry/3373.png (stored 0%)
#   adding: Angry/24678.png (stored 0%)
#   adding: Angry/13675.png (stored 0%)
#   adding: Angry/20943.png (stored 0%)
#   adding: Angry/16999.png (stored 0%)
#   adding: Angry/28412.png (stored 0%)
#   adding: Angry/17731.png (stored 0%)
#   adding: Angry/4579.png (stored 0%)
#   adding: Angry/9809.png (stored 0%)
#   adding: Angry/17153.png (stored 0%)
#   adding: Angry/5598.png (stored 0%)
#   adding: Angry/28248.png (stored 0%)
#   adding: Angry/12235.png (stored 0%)
#   adding: Angry/2455.png (stored 0%)
#   adding: Angry/17650.png (stored 0%)
#   adding: Angry/18375.png (stored 0%)
#   adding: Angry/19735.png (stored 0%)
#   adding: Angry/24033.png (stored 0%)
#   adding: Angry/12489.png (stored 0%)
#   adding: Angry/25807.png (stored 0%)
#   adding: Angry/9389.png (stored 0%)
#   adding: Angry/8922.png (stored 0%)
#   adding: Angry/16912.png (stored 0%)
#   adding: Angry/8858.png (stored 0%)
#   adding: Angry/28062.png (stored 0%)
#   adding: Angry/1927.png (stored 0%)
#   adding: Angry/5244.png (stored 0%)
#   adding: Angry/26259.png (stored 0%)
#   adding: Angry/1639.png (stored 0%)
#   adding: Angry/9770.png (stored 0%)
#   adding: Angry/12304.png (stored 0%)
#   adding: Angry/3667.png (stored 0%)
#   adding: Angry/24345.png (stored 0%)
#   adding: Angry/7578.png (stored 0%)
#   adding: Angry/13934.png (stored 0%)
#   adding: Angry/11289.png (stored 0%)
#   adding: Angry/12474.png (stored 0%)
#   adding: Angry/25767.png (stored 0%)
#   adding: Angry/16605.png (stored 0%)
#   adding: Angry/14147.png (stored 0%)
#   adding: Angry/20130.png (stored 0%)
#   adding: Angry/26178.png (stored 0%)
#   adding: Angry/10325.png (stored 0%)
#   adding: Angry/18935.png (stored 0%)
#   adding: Angry/17868.png (stored 0%)
#   adding: Angry/22892.png (stored 0%)
#   adding: Angry/26719.png (stored 0%)
#   adding: Angry/23005.png (stored 0%)
#   adding: Angry/20582.png (stored 0%)
#   adding: Angry/1422.png (stored 0%)
#   adding: Angry/3759.png (stored 0%)
#   adding: Angry/9802.png (stored 0%)
#   adding: Angry/10154.png (stored 0%)
#   adding: Angry/5962.png (stored 0%)
#   adding: Angry/15654.png (stored 0%)
#   adding: Angry/1340.png (stored 0%)
#   adding: Angry/374.png (stored 0%)
#   adding: Angry/23886.png (stored 0%)
#   adding: Angry/9755.png (stored 0%)
#   adding: Angry/19066.png (stored 0%)
#   adding: Angry/22682.png (stored 0%)
#   adding: Angry/24920.png (stored 0%)
#   adding: Angry/24401.png (stored 0%)
#   adding: Angry/8465.png (stored 0%)
#   adding: Angry/15954.png (stored 0%)
#   adding: Angry/8423.png (stored 0%)
#   adding: Angry/18333.png (stored 0%)
#   adding: Angry/16885.png (stored 0%)
#   adding: Angry/13391.png (stored 0%)
#   adding: Angry/27340.png (stored 0%)
#   adding: Angry/17335.png (stored 0%)
#   adding: Angry/12203.png (stored 0%)
#   adding: Angry/5201.png (stored 0%)
#   adding: Angry/18565.png (stored 0%)
#   adding: Angry/14864.png (stored 0%)
#   adding: Angry/16263.png (stored 0%)
#   adding: Angry/17754.png (stored 0%)
#   adding: Angry/27687.png (stored 0%)
#   adding: Angry/9931.png (stored 0%)
#   adding: Angry/15712.png (stored 0%)
#   adding: Angry/25612.png (stored 0%)
#   adding: Angry/6501.png (stored 0%)
#   adding: Angry/5586.png (stored 0%)
#   adding: Angry/7362.png (stored 0%)
#   adding: Angry/10397.png (stored 0%)
#   adding: Angry/6092.png (stored 0%)
#   adding: Angry/1150.png (stored 0%)
#   adding: Angry/26075.png (stored 0%)
#   adding: Angry/25227.png (stored 0%)
#   adding: Angry/10057.png (stored 0%)
#   adding: Angry/12249.png (stored 0%)
#   adding: Angry/11883.png (stored 0%)
#   adding: Angry/26534.png (stored 0%)
#   adding: Angry/18768.png (stored 0%)
#   adding: Angry/10420.png (stored 0%)
#   adding: Angry/18122.png (stored 0%)
#   adding: Angry/11735.png (stored 0%)
#   adding: Angry/21584.png (stored 0%)
#   adding: Angry/18008.png (stored 0%)
#   adding: Angry/23847.png (stored 0%)
#   adding: Angry/23408.png (stored 0%)
#   adding: Angry/22082.png (stored 0%)
#   adding: Angry/4651.png (stored 0%)
#   adding: Angry/11389.png (stored 0%)
#   adding: Angry/17428.png (stored 0%)
#   adding: Angry/26714.png (stored 0%)
#   adding: Angry/9873.png (stored 0%)
#   adding: Angry/13148.png (deflated 10%)
#   adding: Angry/28511.png (stored 0%)
#   adding: Angry/21063.png (stored 0%)
#   adding: Angry/22858.png (stored 0%)
#   adding: Angry/7807.png (stored 0%)
#   adding: Angry/10382.png (stored 0%)
#   adding: Angry/12613.png (stored 0%)
#   adding: Angry/13125.png (stored 0%)
#   adding: Angry/11464.png (stored 0%)
#   adding: Angry/3327.png (stored 0%)
#   adding: Angry/23810.png (stored 0%)
#   adding: Angry/13210.png (stored 0%)
#   adding: Angry/20017.png (stored 0%)
#   adding: Angry/21613.png (stored 0%)
#   adding: Angry/13019.png (stored 0%)
#   adding: Angry/15709.png (stored 0%)
#   adding: Angry/20227.png (stored 0%)
#   adding: Angry/6576.png (stored 0%)
#   adding: Angry/23196.png (stored 0%)
#   adding: Angry/11887.png (stored 0%)
#   adding: Angry/1880.png (stored 0%)
#   adding: Angry/1651.png (stored 0%)
#   adding: Angry/10970.png (stored 0%)
#   adding: Angry/16297.png (stored 0%)
#   adding: Angry/5204.png (stored 0%)
#   adding: Angry/12552.png (stored 0%)
#   adding: Angry/14338.png (stored 0%)
#   adding: Angry/1242.png (stored 0%)
#   adding: Angry/2081.png (stored 0%)
#   adding: Angry/1018.png (stored 0%)
#   adding: Angry/14108.png (stored 0%)
#   adding: Angry/9258.png (stored 0%)
#   adding: Angry/24372.png (stored 0%)
#   adding: Angry/3320.png (stored 0%)
#   adding: Angry/18271.png (stored 0%)
#   adding: Angry/16292.png (stored 0%)
#   adding: Angry/980.png (stored 0%)
#   adding: Angry/12171.png (stored 0%)
#   adding: Angry/18081.png (stored 0%)
#   adding: Angry/17445.png (stored 0%)
#   adding: Angry/13201.png (stored 0%)
#   adding: Angry/2056.png (stored 0%)
#   adding: Angry/12476.png (stored 0%)
#   adding: Angry/25031.png (stored 0%)
#   adding: Angry/4396.png (stored 0%)
#   adding: Angry/22.png (stored 0%)
#   adding: Angry/19847.png (stored 0%)
#   adding: Angry/25611.png (stored 0%)
#   adding: Angry/11707.png (stored 0%)
#   adding: Angry/1338.png (stored 0%)
#   adding: Angry/26899.png (stored 0%)
#   adding: Angry/10497.png (stored 0%)
#   adding: Angry/9981.png (stored 0%)
#   adding: Angry/24501.png (stored 0%)
#   adding: Angry/7180.png (stored 0%)
#   adding: Angry/10851.png (stored 0%)
#   adding: Angry/13182.png (stored 0%)
#   adding: Angry/3489.png (stored 0%)
#   adding: Angry/19463.png (stored 0%)
#   adding: Angry/25713.png (stored 0%)
#   adding: Angry/6940.png (stored 0%)
#   adding: Angry/966.png (stored 0%)
#   adding: Angry/20044.png (stored 0%)
#   adding: Angry/23118.png (stored 0%)
#   adding: Angry/19093.png (stored 0%)
#   adding: Angry/21018.png (stored 0%)
#   adding: Angry/28660.png (stored 0%)
#   adding: Angry/7358.png (stored 0%)
#   adding: Angry/11169.png (stored 0%)
#   adding: Angry/24350.png (stored 0%)
#   adding: Angry/25094.png (stored 0%)
#   adding: Angry/12198.png (stored 0%)
#   adding: Angry/23.png (stored 0%)
#   adding: Angry/11480.png (stored 0%)
#   adding: Angry/28576.png (stored 0%)
#   adding: Angry/25424.png (stored 0%)
#   adding: Angry/22503.png (stored 0%)
#   adding: Angry/23756.png (stored 0%)
#   adding: Angry/9237.png (stored 0%)
#   adding: Angry/251.png (stored 0%)
#   adding: Angry/5250.png (stored 0%)
#   adding: Angry/727.png (stored 0%)
#   adding: Angry/4937.png (stored 0%)
#   adding: Angry/10215.png (stored 0%)
#   adding: Angry/10900.png (stored 0%)
#   adding: Angry/20901.png (stored 0%)
#   adding: Angry/19502.png (stored 0%)
#   adding: Angry/15327.png (stored 0%)
#   adding: Angry/22226.png (stored 0%)
#   adding: Angry/8273.png (stored 0%)
#   adding: Angry/1766.png (stored 0%)
#   adding: Angry/14511.png (stored 0%)
#   adding: Angry/15020.png (stored 0%)
#   adding: Angry/10973.png (stored 0%)
#   adding: Angry/12404.png (stored 0%)
#   adding: Angry/24428.png (stored 0%)
#   adding: Angry/28641.png (stored 0%)
#   adding: Angry/6745.png (stored 0%)
#   adding: Angry/26764.png (stored 0%)
#   adding: Angry/9266.png (stored 0%)
#   adding: Angry/23834.png (stored 0%)
#   adding: Angry/21204.png (stored 0%)
#   adding: Angry/790.png (stored 0%)
#   adding: Angry/3540.png (stored 0%)
#   adding: Angry/8286.png (stored 0%)
#   adding: Angry/7496.png (stored 0%)
#   adding: Angry/20635.png (stored 0%)
#   adding: Angry/17676.png (stored 0%)
#   adding: Angry/5422.png (stored 0%)
#   adding: Angry/25183.png (stored 0%)
#   adding: Angry/5314.png (stored 0%)
#   adding: Angry/2656.png (stored 0%)
#   adding: Angry/14616.png (stored 0%)
#   adding: Angry/10100.png (stored 0%)
#   adding: Angry/7911.png (stored 0%)
#   adding: Angry/27114.png (stored 0%)
#   adding: Angry/10226.png (stored 0%)
#   adding: Angry/8549.png (stored 0%)
#   adding: Angry/24400.png (stored 0%)
#   adding: Angry/4038.png (stored 0%)
#   adding: Angry/11475.png (stored 0%)
#   adding: Angry/1192.png (stored 0%)
#   adding: Angry/1558.png (stored 0%)
#   adding: Angry/15223.png (stored 0%)
#   adding: Angry/5096.png (stored 0%)
#   adding: Angry/3035.png (stored 0%)
#   adding: Angry/20820.png (stored 0%)
#   adding: Angry/12876.png (stored 0%)
#   adding: Angry/28629.png (stored 0%)
#   adding: Angry/8482.png (stored 0%)
#   adding: Angry/23048.png (stored 0%)
#   adding: Angry/25098.png (stored 0%)
#   adding: Angry/24071.png (stored 0%)
#   adding: Angry/9691.png (stored 0%)
#   adding: Angry/25778.png (stored 0%)
#   adding: Angry/13408.png (stored 0%)
#   adding: Angry/26597.png (stored 0%)
#   adding: Angry/8278.png (stored 0%)
#   adding: Angry/15064.png (stored 0%)
#   adding: Angry/20740.png (stored 0%)
#   adding: Angry/23932.png (stored 0%)
#   adding: Angry/11411.png (stored 0%)
#   adding: Angry/5246.png (stored 0%)
#   adding: Angry/13514.png (stored 0%)
#   adding: Angry/5059.png (stored 0%)
#   adding: Angry/21457.png (stored 0%)
#   adding: Angry/14196.png (stored 0%)
#   adding: Angry/19876.png (stored 0%)
#   adding: Angry/10623.png (stored 0%)
#   adding: Angry/26124.png (stored 0%)
#   adding: Angry/9732.png (stored 0%)
#   adding: Angry/18859.png (stored 0%)
#   adding: Angry/7732.png (stored 0%)
#   adding: Angry/19091.png (stored 0%)
#   adding: Angry/22035.png (stored 0%)
#   adding: Angry/18360.png (stored 0%)
#   adding: Angry/13952.png (stored 0%)
#   adding: Angry/15160.png (stored 0%)
#   adding: Angry/19391.png (stored 0%)
#   adding: Angry/24466.png (stored 0%)
#   adding: Angry/27704.png (stored 0%)
#   adding: Angry/4249.png (stored 0%)
#   adding: Angry/25210.png (stored 0%)
#   adding: Angry/8633.png (stored 0%)
#   adding: Angry/563.png (stored 0%)
#   adding: Angry/1158.png (stored 0%)
#   adding: Angry/22807.png (stored 0%)
#   adding: Angry/6101.png (stored 0%)
#   adding: Angry/7854.png (stored 0%)
#   adding: Angry/10440.png (stored 0%)
#   adding: Angry/9068.png (stored 0%)
#   adding: Angry/21601.png (stored 0%)
#   adding: Angry/1863.png (stored 0%)
#   adding: Angry/21747.png (stored 0%)
#   adding: Angry/10925.png (stored 0%)
#   adding: Angry/20758.png (stored 0%)
#   adding: Angry/13942.png (stored 0%)
#   adding: Angry/13128.png (stored 0%)
#   adding: Angry/3995.png (stored 0%)
#   adding: Angry/23749.png (stored 0%)
#   adding: Angry/24789.png (stored 0%)
#   adding: Angry/23315.png (stored 0%)
#   adding: Angry/23159.png (stored 0%)
#   adding: Angry/17964.png (stored 0%)
#   adding: Angry/9565.png (stored 0%)
#   adding: Angry/1522.png (stored 0%)
#   adding: Angry/21731.png (stored 0%)
#   adding: Angry/9683.png (stored 0%)
#   adding: Angry/23732.png (stored 0%)
#   adding: Angry/22678.png (stored 0%)
#   adding: Angry/12669.png (stored 0%)
#   adding: Angry/19348.png (stored 0%)
#   adding: Angry/24988.png (stored 0%)
#   adding: Angry/21976.png (stored 0%)
#   adding: Angry/7752.png (stored 0%)
#   adding: Angry/6919.png (stored 0%)
#   adding: Angry/23017.png (stored 0%)
#   adding: Angry/8168.png (stored 0%)
#   adding: Angry/14421.png (stored 0%)
#   adding: Angry/13224.png (stored 0%)
#   adding: Angry/27192.png (stored 0%)
#   adding: Angry/25928.png (stored 0%)
#   adding: Angry/10854.png (stored 0%)
#   adding: Angry/5486.png (stored 0%)
#   adding: Angry/21923.png (stored 0%)
#   adding: Angry/13134.png (stored 0%)
#   adding: Angry/20050.png (stored 0%)
#   adding: Angry/7798.png (stored 0%)
#   adding: Angry/1520.png (stored 0%)
#   adding: Angry/23780.png (stored 0%)
#   adding: Angry/12262.png (stored 0%)
#   adding: Angry/27302.png (stored 0%)
#   adding: Angry/16672.png (stored 0%)
#   adding: Angry/26463.png (stored 0%)
#   adding: Angry/15662.png (stored 0%)
#   adding: Angry/3862.png (stored 0%)
#   adding: Angry/5720.png (stored 0%)
#   adding: Angry/7007.png (stored 0%)
#   adding: Angry/17796.png (stored 0%)
#   adding: Angry/25392.png (stored 0%)
#   adding: Angry/27470.png (stored 0%)
#   adding: Angry/169.png (stored 0%)
#   adding: Angry/15505.png (stored 0%)
#   adding: Angry/18434.png (stored 0%)
#   adding: Angry/22656.png (stored 0%)
#   adding: Angry/27113.png (stored 0%)
#   adding: Angry/4693.png (stored 0%)
#   adding: Angry/15002.png (stored 0%)
#   adding: Angry/9685.png (stored 0%)
#   adding: Angry/3580.png (stored 0%)
#   adding: Angry/3817.png (stored 0%)
#   adding: Angry/18808.png (stored 0%)
#   adding: Angry/26240.png (stored 0%)
#   adding: Angry/9461.png (stored 0%)
#   adding: Angry/21176.png (stored 0%)
#   adding: Angry/10371.png (stored 0%)
#   adding: Angry/3119.png (stored 0%)
#   adding: Angry/22242.png (stored 0%)
#   adding: Angry/16659.png (stored 0%)
#   adding: Angry/16240.png (stored 0%)
#   adding: Angry/18781.png (stored 0%)
#   adding: Angry/28489.png (stored 0%)
#   adding: Angry/9785.png (stored 0%)
#   adding: Angry/14426.png (stored 0%)
#   adding: Angry/5633.png (stored 0%)
#   adding: Angry/13057.png (stored 0%)
#   adding: Angry/19671.png (stored 0%)
#   adding: Angry/12962.png (stored 0%)
#   adding: Angry/5747.png (stored 0%)
#   adding: Angry/10913.png (stored 0%)
#   adding: Angry/9452.png (stored 0%)
#   adding: Angry/8749.png (stored 0%)
#   adding: Angry/5939.png (stored 0%)
#   adding: Angry/24147.png (stored 0%)
#   adding: Angry/15771.png (stored 0%)
#   adding: Angry/4196.png (stored 0%)
#   adding: Angry/27545.png (stored 0%)
#   adding: Angry/17735.png (stored 0%)
#   adding: Angry/26868.png (stored 0%)
#   adding: Angry/5439.png (stored 0%)
#   adding: Angry/6082.png (stored 0%)
#   adding: Angry/16648.png (stored 0%)
#   adding: Angry/15074.png (stored 0%)
#   adding: Angry/8413.png (stored 0%)
#   adding: Angry/24883.png (stored 0%)
#   adding: Angry/1372.png (stored 0%)
#   adding: Angry/1468.png (stored 0%)
#   adding: Angry/14357.png (stored 0%)
#   adding: Angry/7790.png (stored 0%)
#   adding: Angry/14856.png (stored 0%)
#   adding: Angry/24704.png (stored 0%)
#   adding: Angry/25964.png (stored 0%)
#   adding: Angry/13324.png (stored 0%)
#   adding: Angry/25060.png (stored 0%)
#   adding: Angry/3188.png (stored 0%)
#   adding: Angry/15330.png (stored 0%)
#   adding: Angry/10692.png (stored 0%)
#   adding: Angry/9876.png (stored 0%)
#   adding: Angry/15644.png (stored 0%)
#   adding: Angry/27982.png (stored 0%)
#   adding: Angry/26414.png (stored 0%)
#   adding: Angry/946.png (stored 0%)
#   adding: Angry/1071.png (stored 0%)
#   adding: Angry/18608.png (stored 0%)
#   adding: Angry/3801.png (stored 0%)
#   adding: Angry/27491.png (stored 0%)
#   adding: Angry/19520.png (stored 0%)
#   adding: Angry/13781.png (stored 0%)
#   adding: Angry/4341.png (stored 0%)
#   adding: Angry/27809.png (stored 0%)
#   adding: Angry/23423.png (stored 0%)
#   adding: Angry/7637.png (stored 0%)
#   adding: Angry/6490.png (stored 0%)
#   adding: Angry/10511.png (stored 0%)
#   adding: Angry/28226.png (stored 0%)
#   adding: Angry/21609.png (stored 0%)
#   adding: Angry/2558.png (stored 0%)
#   adding: Angry/5067.png (stored 0%)
#   adding: Angry/17495.png (stored 0%)
#   adding: Angry/8826.png (stored 0%)
#   adding: Angry/16527.png (stored 0%)
#   adding: Angry/25886.png (stored 0%)
#   adding: Angry/16397.png (stored 0%)
#   adding: Angry/9501.png (stored 0%)
#   adding: Angry/23230.png (stored 0%)
#   adding: Angry/27991.png (stored 0%)
#   adding: Angry/10959.png (stored 0%)
#   adding: Angry/19541.png (stored 0%)
#   adding: Angry/12972.png (stored 0%)
#   adding: Angry/10619.png (stored 0%)
#   adding: Angry/8169.png (stored 0%)
#   adding: Angry/280.png (stored 0%)
#   adding: Angry/23004.png (stored 0%)
#   adding: Angry/22725.png (stored 0%)
#   adding: Angry/3606.png (stored 0%)
#   adding: Angry/10178.png (stored 0%)
#   adding: Angry/27129.png (stored 0%)
#   adding: Angry/14143.png (stored 0%)
#   adding: Angry/21836.png (stored 0%)
#   adding: Angry/19413.png (stored 0%)
#   adding: Angry/499.png (stored 0%)
#   adding: Angry/4818.png (stored 0%)
#   adding: Angry/9104.png (stored 0%)
#   adding: Angry/9196.png (stored 0%)
#   adding: Angry/25019.png (stored 0%)
#   adding: Angry/27448.png (stored 0%)
#   adding: Angry/2791.png (stored 0%)
#   adding: Angry/28146.png (stored 0%)
#   adding: Angry/18415.png (stored 0%)
#   adding: Angry/16193.png (stored 0%)
#   adding: Angry/1.png (stored 0%)
#   adding: Angry/25347.png (stored 0%)
#   adding: Angry/4955.png (stored 0%)
#   adding: Angry/27096.png (stored 0%)
#   adding: Angry/14445.png (stored 0%)
#   adding: Angry/21509.png (stored 0%)
#   adding: Angry/15410.png (stored 0%)
#   adding: Angry/6294.png (stored 0%)
#   adding: Angry/21463.png (stored 0%)
#   adding: Angry/6581.png (stored 0%)
#   adding: Angry/3137.png (stored 0%)
#   adding: Angry/10947.png (stored 0%)
#   adding: Angry/2020.png (stored 0%)
#   adding: Angry/25866.png (stored 0%)
#   adding: Angry/23640.png (stored 0%)
#   adding: Angry/5902.png (stored 0%)
#   adding: Angry/26471.png (stored 0%)
#   adding: Angry/17835.png (stored 0%)
#   adding: Angry/2909.png (stored 0%)
#   adding: Angry/233.png (stored 0%)
#   adding: Angry/28134.png (stored 0%)
#   adding: Angry/11632.png (stored 0%)
#   adding: Angry/21038.png (stored 0%)
#   adding: Angry/25739.png (stored 0%)
#   adding: Angry/24430.png (stored 0%)
#   adding: Angry/16875.png (stored 0%)
#   adding: Angry/16871.png (stored 0%)
#   adding: Angry/24407.png (stored 0%)
#   adding: Angry/20183.png (stored 0%)
#   adding: Angry/3819.png (stored 0%)
#   adding: Angry/17256.png (stored 0%)
#   adding: Angry/25082.png (stored 0%)
#   adding: Angry/20539.png (stored 0%)
#   adding: Angry/8535.png (stored 0%)
#   adding: Angry/14827.png (stored 0%)
#   adding: Angry/122.png (stored 0%)
#   adding: Angry/3080.png (stored 0%)
#   adding: Angry/21173.png (stored 0%)
#   adding: Angry/3990.png (stored 0%)
#   adding: Angry/10961.png (stored 0%)
#   adding: Angry/9041.png (stored 0%)
#   adding: Angry/20977.png (stored 0%)
#   adding: Angry/4349.png (stored 0%)
#   adding: Angry/157.png (stored 0%)
#   adding: Angry/3113.png (stored 0%)
#   adding: Angry/4060.png (stored 0%)
#   adding: Angry/8120.png (stored 0%)
#   adding: Angry/15902.png (stored 0%)
#   adding: Angry/5014.png (stored 0%)
#   adding: Angry/16189.png (stored 0%)
#   adding: Angry/9552.png (stored 0%)
#   adding: Angry/21622.png (stored 0%)
#   adding: Angry/19060.png (stored 0%)
#   adding: Angry/2144.png (stored 0%)
#   adding: Angry/18707.png (stored 0%)
#   adding: Angry/16643.png (stored 0%)
#   adding: Angry/26804.png (stored 0%)
#   adding: Angry/5528.png (stored 0%)
#   adding: Angry/7457.png (stored 0%)
#   adding: Angry/26681.png (stored 0%)
#   adding: Angry/22273.png (stored 0%)
#   adding: Angry/18391.png (stored 0%)
#   adding: Angry/2066.png (stored 0%)
#   adding: Angry/1508.png (stored 0%)
#   adding: Angry/28607.png (stored 0%)
#   adding: Angry/19292.png (stored 0%)
#   adding: Angry/9156.png (stored 0%)
#   adding: Angry/6687.png (stored 0%)
#   adding: Angry/6566.png (stored 0%)
#   adding: Angry/5659.png (stored 0%)
#   adding: Angry/9753.png (stored 0%)
#   adding: Angry/249.png (stored 0%)
#   adding: Angry/16012.png (stored 0%)
#   adding: Angry/18166.png (stored 0%)
#   adding: Angry/14313.png (stored 0%)
#   adding: Angry/23169.png (stored 0%)
#   adding: Angry/28705.png (stored 0%)
#   adding: Angry/23468.png (stored 0%)
#   adding: Angry/13452.png (stored 0%)
#   adding: Angry/21921.png (stored 0%)
#   adding: Angry/2103.png (stored 0%)
#   adding: Angry/854.png (stored 0%)
#   adding: Angry/8001.png (stored 0%)
#   adding: Angry/6618.png (stored 0%)
#   adding: Angry/3702.png (stored 0%)
#   adding: Angry/5221.png (stored 0%)
#   adding: Angry/23532.png (stored 0%)
#   adding: Angry/17714.png (stored 0%)
#   adding: Angry/27590.png (stored 0%)
#   adding: Angry/28571.png (stored 0%)
#   adding: Angry/26123.png (stored 0%)
#   adding: Angry/20808.png (stored 0%)
#   adding: Angry/16011.png (stored 0%)
#   adding: Angry/120.png (stored 0%)
#   adding: Angry/4665.png (stored 0%)
#   adding: Angry/7322.png (stored 0%)
#   adding: Angry/25944.png (stored 0%)
#   adding: Angry/23536.png (stored 0%)
#   adding: Angry/18903.png (stored 0%)
#   adding: Angry/20627.png (stored 0%)
#   adding: Angry/2055.png (stored 0%)
#   adding: Angry/2260.png (stored 0%)
#   adding: Angry/19512.png (stored 0%)
#   adding: Angry/14758.png (stored 0%)
#   adding: Angry/17729.png (stored 0%)
#   adding: Angry/27612.png (stored 0%)
#   adding: Angry/20110.png (stored 0%)
#   adding: Angry/824.png (stored 0%)
#   adding: Angry/13418.png (stored 0%)
#   adding: Angry/25795.png (stored 0%)
#   adding: Angry/12027.png (stored 0%)
#   adding: Angry/12710.png (stored 0%)
#   adding: Angry/26437.png (stored 0%)
#   adding: Angry/16410.png (stored 0%)
#   adding: Angry/5925.png (stored 0%)
#   adding: Angry/1966.png (stored 0%)
#   adding: Angry/24326.png (stored 0%)
#   adding: Angry/26051.png (stored 0%)
#   adding: Angry/27008.png (stored 0%)
#   adding: Angry/1717.png (stored 0%)
#   adding: Angry/27397.png (stored 0%)
#   adding: Angry/2897.png (stored 0%)
#   adding: Angry/7197.png (stored 0%)
#   adding: Angry/12817.png (stored 0%)
#   adding: Angry/15903.png (stored 0%)
#   adding: Angry/1899.png (stored 0%)
#   adding: Angry/15997.png (stored 0%)
#   adding: Angry/6390.png (stored 0%)
#   adding: Angry/4100.png (stored 0%)
#   adding: Angry/8134.png (stored 0%)
#   adding: Angry/11190.png (stored 0%)
#   adding: Angry/1061.png (stored 0%)
#   adding: Angry/12451.png (stored 0%)
#   adding: Angry/17764.png (stored 0%)
#   adding: Angry/5296.png (stored 0%)
#   adding: Angry/10928.png (stored 0%)
#   adding: Angry/16506.png (stored 0%)
#   adding: Angry/18418.png (stored 0%)
#   adding: Angry/2903.png (stored 0%)
#   adding: Angry/11458.png (stored 0%)
#   adding: Angry/24593.png (stored 0%)
#   adding: Angry/21277.png (stored 0%)
#   adding: Angry/12456.png (stored 0%)
#   adding: Angry/19656.png (stored 0%)
#   adding: Angry/24961.png (stored 0%)
#   adding: Angry/24839.png (stored 0%)
#   adding: Angry/15363.png (stored 0%)
#   adding: Angry/15433.png (stored 0%)
#   adding: Angry/14439.png (stored 0%)
#   adding: Angry/9249.png (stored 0%)
#   adding: Angry/6702.png (stored 0%)
#   adding: Angry/20997.png (stored 0%)
#   adding: Angry/18892.png (stored 0%)
#   adding: Angry/16379.png (stored 0%)
#   adding: Angry/22948.png (stored 0%)
#   adding: Angry/15261.png (stored 0%)
#   adding: Angry/27609.png (stored 0%)
#   adding: Angry/27151.png (stored 0%)
#   adding: Angry/7056.png (stored 0%)
#   adding: Angry/12283.png (stored 0%)
#   adding: Angry/24959.png (stored 0%)
#   adding: Angry/15637.png (stored 0%)
#   adding: Angry/6853.png (stored 0%)
#   adding: Angry/2264.png (stored 0%)
#   adding: Angry/28458.png (stored 0%)
#   adding: Angry/23961.png (stored 0%)
#   adding: Angry/22782.png (stored 0%)
#   adding: Angry/11377.png (stored 0%)
#   adding: Angry/17679.png (stored 0%)
#   adding: Angry/4364.png (stored 0%)
#   adding: Angry/15848.png (stored 0%)
#   adding: Angry/12365.png (stored 0%)
#   adding: Angry/18829.png (stored 0%)
#   adding: Angry/25598.png (stored 0%)
#   adding: Angry/6131.png (stored 0%)
#   adding: Angry/8545.png (stored 0%)
#   adding: Angry/9404.png (stored 0%)
#   adding: Angry/11882.png (stored 0%)
#   adding: Angry/18621.png (stored 0%)
#   adding: Angry/25345.png (stored 0%)
#   adding: Angry/11694.png (stored 0%)
#   adding: Angry/24116.png (stored 0%)
#   adding: Angry/2031.png (stored 0%)
#   adding: Angry/24895.png (stored 0%)
#   adding: Angry/28498.png (stored 0%)
#   adding: Angry/1806.png (stored 0%)
#   adding: Angry/4429.png (stored 0%)
#   adding: Angry/10251.png (stored 0%)
#   adding: Angry/4808.png (stored 0%)
#   adding: Angry/19631.png (stored 0%)
#   adding: Angry/7587.png (stored 0%)
#   adding: Angry/16681.png (stored 0%)
#   adding: Angry/17393.png (stored 0%)
#   adding: Angry/5610.png (stored 0%)
#   adding: Angry/22441.png (stored 0%)
#   adding: Angry/8902.png (stored 0%)
#   adding: Angry/3482.png (stored 0%)
#   adding: Angry/24821.png (stored 0%)
#   adding: Angry/5045.png (stored 0%)
#   adding: Angry/11756.png (stored 0%)
#   adding: Angry/22183.png (stored 0%)
#   adding: Angry/5060.png (stored 0%)
#   adding: Angry/7415.png (stored 0%)
#   adding: Angry/26725.png (stored 0%)
#   adding: Angry/21703.png (stored 0%)
#   adding: Angry/28389.png (stored 0%)
#   adding: Angry/8515.png (stored 0%)
#   adding: Angry/27875.png (stored 0%)
#   adding: Angry/117.png (stored 0%)
#   adding: Angry/11617.png (stored 0%)
#   adding: Angry/14739.png (stored 0%)
#   adding: Angry/19688.png (stored 0%)
#   adding: Angry/5428.png (stored 0%)
#   adding: Angry/1200.png (stored 0%)
#   adding: Angry/2247.png (stored 0%)
#   adding: Angry/4708.png (stored 0%)
#   adding: Angry/4514.png (stored 0%)
#   adding: Angry/24435.png (stored 0%)
#   adding: Angry/3558.png (stored 0%)
#   adding: Angry/22209.png (stored 0%)
#   adding: Angry/6620.png (stored 0%)
#   adding: Angry/16652.png (stored 0%)
#   adding: Angry/23059.png (stored 0%)
#   adding: Angry/19766.png (stored 0%)
#   adding: Angry/27909.png (stored 0%)
#   adding: Angry/19067.png (stored 0%)
#   adding: Angry/10939.png (stored 0%)
#   adding: Angry/13094.png (stored 0%)
#   adding: Angry/25000.png (stored 0%)
#   adding: Angry/9383.png (stored 0%)
#   adding: Angry/23589.png (stored 0%)
#   adding: Angry/26291.png (stored 0%)
#   adding: Angry/25977.png (stored 0%)
#   adding: Angry/21576.png (stored 0%)
#   adding: Angry/15562.png (stored 0%)
#   adding: Angry/5737.png (stored 0%)
#   adding: Angry/4438.png (stored 0%)
#   adding: Angry/18403.png (stored 0%)
#   adding: Angry/9208.png (stored 0%)
#   adding: Angry/20649.png (stored 0%)
#   adding: Angry/13141.png (stored 0%)
#   adding: Angry/9862.png (stored 0%)
#   adding: Angry/10984.png (stored 0%)
#   adding: Angry/21573.png (stored 0%)
#   adding: Angry/28436.png (stored 0%)
#   adding: Angry/9468.png (stored 0%)
#   adding: Angry/12316.png (stored 0%)
#   adding: Angry/13967.png (stored 0%)
#   adding: Angry/11460.png (stored 0%)
#   adding: Angry/496.png (stored 0%)
#   adding: Angry/17354.png (stored 0%)
#   adding: Angry/10399.png (stored 0%)
#   adding: Angry/25137.png (stored 0%)
#   adding: Angry/5268.png (stored 0%)
#   adding: Angry/15381.png (stored 0%)
#   adding: Angry/15779.png (stored 0%)
#   adding: Angry/7711.png (stored 0%)
#   adding: Angry/1211.png (stored 0%)
#   adding: Angry/7921.png (stored 0%)
#   adding: Angry/28152.png (stored 0%)
#   adding: Angry/4638.png (stored 0%)
#   adding: Angry/12421.png (stored 0%)
#   adding: Angry/17787.png (stored 0%)
#   adding: Angry/22733.png (stored 0%)
#   adding: Angry/5460.png (stored 0%)
#   adding: Angry/13345.png (stored 0%)
#   adding: Angry/27296.png (stored 0%)
#   adding: Angry/13950.png (stored 0%)
#   adding: Angry/21050.png (stored 0%)
#   adding: Angry/5525.png (stored 0%)
#   adding: Angry/150.png (stored 0%)
#   adding: Angry/20915.png (stored 0%)
#   adding: Angry/27346.png (stored 0%)
#   adding: Angry/16484.png (stored 0%)
#   adding: Angry/22148.png (stored 0%)
#   adding: Angry/14266.png (stored 0%)
#   adding: Angry/4842.png (stored 0%)
#   adding: Angry/18107.png (stored 0%)
#   adding: Angry/5118.png (stored 0%)
#   adding: Angry/2070.png (stored 0%)
#   adding: Angry/24908.png (stored 0%)
#   adding: Angry/2142.png (stored 0%)
#   adding: Angry/9591.png (stored 0%)
#   adding: Angry/21762.png (stored 0%)
#   adding: Angry/1597.png (stored 0%)
#   adding: Angry/27020.png (stored 0%)
#   adding: Angry/14056.png (stored 0%)
#   adding: Angry/21372.png (stored 0%)
#   adding: Angry/633.png (stored 0%)
#   adding: Angry/6589.png (stored 0%)
#   adding: Angry/12540.png (stored 0%)
#   adding: Angry/9342.png (stored 0%)
#   adding: Angry/6531.png (stored 0%)
#   adding: Angry/17571.png (stored 0%)
#   adding: Angry/7360.png (stored 0%)
#   adding: Angry/25844.png (stored 0%)
#   adding: Angry/15706.png (stored 0%)
#   adding: Angry/23375.png (stored 0%)
#   adding: Angry/263.png (stored 0%)
#   adding: Angry/16603.png (stored 0%)
#   adding: Angry/7238.png (stored 0%)
#   adding: Angry/23632.png (stored 0%)
#   adding: Angry/22426.png (stored 0%)
#   adding: Angry/671.png (stored 0%)
#   adding: Angry/19058.png (stored 0%)
#   adding: Angry/9563.png (stored 0%)
#   adding: Angry/23437.png (stored 0%)
#   adding: Angry/26298.png (stored 0%)
#   adding: Angry/11613.png (stored 0%)
#   adding: Angry/7389.png (stored 0%)
#   adding: Angry/14095.png (stored 0%)
#   adding: Angry/7838.png (stored 0%)
#   adding: Angry/5259.png (stored 0%)
#   adding: Angry/10265.png (stored 0%)
#   adding: Angry/14936.png (stored 0%)
#   adding: Angry/2778.png (stored 0%)
#   adding: Angry/7374.png (stored 0%)
#   adding: Angry/3699.png (stored 0%)
#   adding: Angry/5129.png (stored 0%)
#   adding: Angry/15594.png (stored 0%)
#   adding: Angry/12667.png (stored 0%)
#   adding: Angry/23840.png (stored 0%)
#   adding: Angry/2117.png (stored 0%)
#   adding: Angry/700.png (stored 0%)
#   adding: Angry/834.png (stored 0%)
#   adding: Angry/6413.png (stored 0%)
#   adding: Angry/14614.png (stored 0%)
#   adding: Angry/16323.png (stored 0%)
#   adding: Angry/7983.png (stored 0%)
#   adding: Angry/14018.png (stored 0%)
#   adding: Angry/21161.png (stored 0%)
#   adding: Angry/7796.png (stored 0%)
#   adding: Angry/25437.png (stored 0%)
#   adding: Angry/14296.png (stored 0%)
#   adding: Angry/9729.png (stored 0%)
#   adding: Angry/4742.png (stored 0%)
#   adding: Angry/7979.png (stored 0%)
#   adding: Angry/19685.png (stored 0%)
#   adding: Angry/8547.png (stored 0%)
#   adding: Angry/9950.png (stored 0%)
#   adding: Angry/24331.png (stored 0%)
#   adding: Angry/20470.png (stored 0%)
#   adding: Angry/4082.png (stored 0%)
#   adding: Angry/20505.png (stored 0%)
#   adding: Angry/21370.png (stored 0%)
#   adding: Angry/27304.png (stored 0%)
#   adding: Angry/13095.png (stored 0%)
#   adding: Angry/3032.png (stored 0%)
#   adding: Angry/7550.png (stored 0%)
#   adding: Angry/27481.png (stored 0%)
#   adding: Angry/10823.png (stored 0%)
#   adding: Angry/17633.png (stored 0%)
#   adding: Angry/2890.png (stored 0%)
#   adding: Angry/7514.png (stored 0%)
#   adding: Angry/5399.png (stored 0%)
#   adding: Angry/4701.png (stored 0%)
#   adding: Angry/93.png (stored 0%)
#   adding: Angry/5387.png (stored 0%)
#   adding: Angry/6632.png (stored 0%)
#   adding: Angry/7688.png (stored 0%)
#   adding: Angry/22641.png (stored 0%)
#   adding: Angry/23473.png (stored 0%)
#   adding: Angry/18000.png (stored 0%)
#   adding: Angry/20960.png (stored 0%)
#   adding: Angry/1694.png (stored 0%)
#   adding: Angry/7956.png (stored 0%)
#   adding: Angry/19939.png (stored 0%)
#   adding: Angry/28349.png (stored 0%)
#   adding: Angry/17167.png (stored 0%)
#   adding: Angry/197.png (stored 0%)
#   adding: Angry/17768.png (stored 0%)
#   adding: Angry/26933.png (stored 0%)
#   adding: Angry/1215.png (stored 0%)
#   adding: Angry/3602.png (stored 0%)
#   adding: Angry/2762.png (stored 0%)
#   adding: Angry/4193.png (stored 0%)
#   adding: Angry/25515.png (stored 0%)
#   adding: Angry/14460.png (stored 0%)
#   adding: Angry/25833.png (stored 0%)
#   adding: Angry/20643.png (stored 0%)
#   adding: Angry/15321.png (stored 0%)
#   adding: Angry/6642.png (stored 0%)
#   adding: Angry/2743.png (stored 0%)
#   adding: Angry/22068.png (stored 0%)
#   adding: Angry/1108.png (stored 0%)
#   adding: Angry/22024.png (stored 0%)
#   adding: Angry/15133.png (stored 0%)
#   adding: Angry/4678.png (stored 0%)
#   adding: Angry/3227.png (stored 0%)
#   adding: Angry/2410.png (stored 0%)
#   adding: Angry/18668.png (stored 0%)
#   adding: Angry/7090.png (stored 0%)
#   adding: Angry/18140.png (stored 0%)
#   adding: Angry/23404.png (stored 0%)
#   adding: Angry/11420.png (stored 0%)
#   adding: Angry/26860.png (stored 0%)
#   adding: Angry/18423.png (stored 0%)
#   adding: Angry/24265.png (stored 0%)
#   adding: Angry/4021.png (stored 0%)
#   adding: Angry/9535.png (stored 0%)
#   adding: Angry/19140.png (stored 0%)
#   adding: Angry/23521.png (stored 0%)
#   adding: Angry/25291.png (stored 0%)
#   adding: Angry/24327.png (stored 0%)
#   adding: Angry/714.png (stored 0%)
#   adding: Angry/1533.png (stored 0%)
#   adding: Angry/11561.png (stored 0%)
#   adding: Angry/842.png (stored 0%)
#   adding: Angry/20795.png (stored 0%)
#   adding: Angry/13582.png (stored 0%)
#   adding: Angry/22513.png (stored 0%)
#   adding: Angry/13941.png (stored 0%)
#   adding: Angry/22516.png (stored 0%)
#   adding: Angry/24132.png (stored 0%)
#   adding: Angry/11028.png (stored 0%)
#   adding: Angry/25974.png (stored 0%)
#   adding: Angry/21447.png (stored 0%)
#   adding: Angry/9905.png (stored 0%)
#   adding: Angry/25663.png (stored 0%)
#   adding: Angry/21013.png (stored 0%)
#   adding: Angry/20629.png (stored 0%)
#   adding: Angry/11467.png (stored 0%)
#   adding: Angry/1370.png (stored 0%)
#   adding: Angry/12419.png (stored 0%)
#   adding: Angry/9767.png (stored 0%)
#   adding: Angry/14791.png (stored 0%)
#   adding: Angry/21168.png (stored 0%)
#   adding: Angry/20451.png (stored 0%)
#   adding: Angry/5332.png (stored 0%)
#   adding: Angry/14376.png (stored 0%)
#   adding: Angry/15894.png (deflated 10%)
#   adding: Angry/27863.png (stored 0%)
#   adding: Angry/10714.png (stored 0%)
#   adding: Angry/8224.png (stored 0%)
#   adding: Angry/9403.png (stored 0%)
#   adding: Angry/26334.png (stored 0%)
#   adding: Angry/12367.png (stored 0%)
#   adding: Angry/12970.png (stored 0%)
#   adding: Angry/3303.png (stored 0%)
#   adding: Angry/13673.png (stored 0%)
#   adding: Angry/22990.png (stored 0%)
#   adding: Angry/22059.png (stored 0%)
#   adding: Angry/1016.png (stored 0%)
#   adding: Angry/18760.png (stored 0%)
#   adding: Angry/7134.png (stored 0%)
#   adding: Angry/14831.png (stored 0%)
#   adding: Angry/7370.png (stored 0%)
#   adding: Angry/13029.png (stored 0%)
#   adding: Angry/2525.png (stored 0%)
#   adding: Angry/20827.png (stored 0%)
#   adding: Angry/25144.png (stored 0%)
#   adding: Angry/16916.png (stored 0%)
#   adding: Angry/23686.png (stored 0%)
#   adding: Angry/5607.png (stored 0%)
#   adding: Angry/21068.png (stored 0%)
#   adding: Angry/24622.png (stored 0%)
#   adding: Angry/14961.png (stored 0%)
#   adding: Angry/2646.png (stored 0%)
#   adding: Angry/5896.png (stored 0%)
#   adding: Angry/21511.png (stored 0%)
#   adding: Angry/25493.png (stored 0%)
#   adding: Angry/18912.png (stored 0%)
#   adding: Angry/8769.png (stored 0%)
#   adding: Angry/7487.png (stored 0%)
#   adding: Angry/23766.png (stored 0%)
#   adding: Angry/27691.png (stored 0%)
#   adding: Angry/24686.png (stored 0%)
#   adding: Angry/18880.png (stored 0%)
#   adding: Angry/28193.png (stored 0%)
#   adding: Angry/5546.png (stored 0%)
#   adding: Angry/6965.png (stored 0%)
#   adding: Angry/23314.png (stored 0%)
#   adding: Angry/10196.png (stored 0%)
#   adding: Angry/1124.png (stored 0%)
#   adding: Angry/24121.png (stored 0%)
#   adding: Angry/14640.png (stored 0%)
#   adding: Angry/7011.png (stored 0%)
#   adding: Angry/1443.png (stored 0%)
#   adding: Angry/9748.png (stored 0%)
#   adding: Angry/4180.png (stored 0%)
#   adding: Angry/4585.png (stored 0%)
#   adding: Angry/26964.png (stored 0%)
#   adding: Angry/28111.png (stored 0%)
#   adding: Angry/24084.png (stored 0%)
#   adding: Angry/7241.png (stored 0%)
#   adding: Angry/26432.png (stored 0%)
#   adding: Angry/8271.png (stored 0%)
#   adding: Angry/25891.png (stored 0%)
#   adding: Angry/23705.png (stored 0%)
#   adding: Angry/3330.png (stored 0%)
#   adding: Angry/27284.png (stored 0%)
#   adding: Angry/2749.png (stored 0%)
#   adding: Angry/16233.png (stored 0%)
#   adding: Angry/24970.png (stored 0%)
#   adding: Angry/8422.png (stored 0%)
#   adding: Angry/23877.png (stored 0%)
#   adding: Angry/17352.png (stored 0%)
#   adding: Angry/13738.png (stored 0%)
#   adding: Angry/19108.png (stored 0%)
#   adding: Angry/26700.png (stored 0%)
#   adding: Angry/21415.png (stored 0%)
#   adding: Angry/9418.png (stored 0%)
#   adding: Angry/12475.png (stored 0%)
#   adding: Angry/28463.png (stored 0%)
#   adding: Angry/17298.png (stored 0%)
#   adding: Angry/20798.png (stored 0%)
#   adding: Angry/20755.png (stored 0%)
#   adding: Angry/15897.png (stored 0%)
#   adding: Angry/5850.png (stored 0%)
#   adding: Angry/22880.png (stored 0%)
#   adding: Angry/28198.png (stored 0%)
#   adding: Angry/7082.png (stored 0%)
#   adding: Angry/5162.png (stored 0%)
#   adding: Angry/12746.png (stored 0%)
#   adding: Angry/21728.png (stored 0%)
#   adding: Angry/19262.png (stored 0%)
#   adding: Angry/16516.png (stored 0%)
#   adding: Angry/1849.png (stored 0%)
#   adding: Angry/27462.png (stored 0%)
#   adding: Angry/13399.png (stored 0%)
#   adding: Angry/8767.png (stored 0%)
#   adding: Angry/24412.png (stored 0%)
#   adding: Angry/25237.png (stored 0%)
#   adding: Angry/2498.png (stored 0%)
#   adding: Angry/4208.png (stored 0%)
#   adding: Angry/1453.png (stored 0%)
#   adding: Angry/20640.png (stored 0%)
#   adding: Angry/16737.png (stored 0%)
#   adding: Angry/20004.png (stored 0%)
#   adding: Angry/22660.png (stored 0%)
#   adding: Angry/28518.png (stored 0%)
#   adding: Angry/25283.png (stored 0%)
#   adding: Angry/14438.png (stored 0%)
#   adding: Angry/19360.png (stored 0%)
#   adding: Angry/6274.png (stored 0%)
#   adding: Angry/5542.png (stored 0%)
#   adding: Angry/6458.png (deflated 10%)
#   adding: Angry/24138.png (stored 0%)
#   adding: Angry/2386.png (stored 0%)
#   adding: Angry/25169.png (stored 0%)
#   adding: Angry/24549.png (stored 0%)
#   adding: Angry/10038.png (stored 0%)
#   adding: Angry/18254.png (stored 0%)
#   adding: Angry/8253.png (stored 0%)
#   adding: Angry/965.png (stored 0%)
#   adding: Angry/9817.png (stored 0%)
#   adding: Angry/14118.png (stored 0%)
#   adding: Angry/23783.png (stored 0%)
#   adding: Angry/4118.png (stored 0%)
#   adding: Angry/17797.png (stored 0%)
#   adding: Angry/24256.png (stored 0%)
#   adding: Angry/5041.png (stored 0%)
#   adding: Angry/28030.png (stored 0%)
#   adding: Angry/20686.png (stored 0%)
#   adding: Angry/24021.png (stored 0%)
#   adding: Angry/25853.png (stored 0%)
#   adding: Angry/17791.png (stored 0%)
#   adding: Angry/12681.png (stored 0%)
#   adding: Angry/20237.png (stored 0%)
#   adding: Angry/17235.png (stored 0%)
#   adding: Angry/16424.png (stored 0%)
#   adding: Angry/22329.png (stored 0%)
#   adding: Angry/25361.png (stored 0%)
#   adding: Angry/10889.png (stored 0%)
#   adding: Angry/22773.png (stored 0%)
#   adding: Angry/3171.png (stored 0%)
#   adding: Angry/18200.png (stored 0%)
#   adding: Angry/10988.png (stored 0%)
#   adding: Angry/11186.png (stored 0%)
#   adding: Angry/18305.png (stored 0%)
#   adding: Angry/22400.png (stored 0%)
#   adding: Angry/18189.png (stored 0%)
#   adding: Angry/19551.png (stored 0%)
#   adding: Angry/16428.png (stored 0%)
#   adding: Angry/1731.png (stored 0%)
#   adding: Angry/19327.png (stored 0%)
#   adding: Angry/10462.png (stored 0%)
#   adding: Angry/28534.png (stored 0%)
#   adding: Angry/15962.png (stored 0%)
#   adding: Angry/27744.png (stored 0%)
#   adding: Angry/16316.png (stored 0%)
#   adding: Angry/1122.png (stored 0%)
#   adding: Angry/4670.png (stored 0%)
#   adding: Angry/5400.png (stored 0%)
#   adding: Angry/27327.png (stored 0%)
#   adding: Angry/1668.png (stored 0%)
#   adding: Angry/27413.png (stored 0%)
#   adding: Angry/4018.png (stored 0%)
#   adding: Angry/409.png (stored 0%)
#   adding: Angry/18899.png (stored 0%)
#   adding: Angry/15418.png (stored 0%)
# ...
#   adding: Surprise/32324.png (stored 0%)
#   adding: Surprise/34680.png (stored 0%)
#   adding: Surprise/34111.png (stored 0%)
#   adding: Surprise/33306.png (stored 0%)
#   adding: Surprise/33950.png (stored 0%)
#   adding: Surprise/34546.png (stored 0%)
#   adding: Surprise/35063.png (stored 0%)
#   adding: Surprise/35875.png (stored 0%)
#   adding: Surprise/35390.png (stored 0%)
#   adding: Surprise/35513.png (stored 0%)
#   adding: Surprise/35175.png (stored 0%)
#   adding: Surprise/33866.png (stored 0%)
#   adding: Surprise/33931.png (stored 0%)
#   adding: Surprise/35562.png (stored 0%)
#   adding: Surprise/34984.png (stored 0%)
#   adding: Surprise/34340.png (stored 0%)
#   adding: Surprise/34449.png (stored 0%)
#   adding: Surprise/34499.png (stored 0%)
#   adding: Surprise/34784.png (stored 0%)
#   adding: Surprise/34039.png (stored 0%)
#   adding: Surprise/34136.png (stored 0%)
#   adding: Surprise/35738.png (stored 0%)
#   adding: Surprise/35049.png (stored 0%)
#   adding: Surprise/33907.png (stored 0%)
#   adding: Surprise/34009.png (stored 0%)
#   adding: Surprise/34395.png (stored 0%)
#   adding: Surprise/33458.png (stored 0%)
#   adding: Surprise/34611.png (stored 0%)
#   adding: Surprise/33963.png (stored 0%)
#   adding: Surprise/34664.png (stored 0%)
#   adding: Surprise/32652.png (stored 0%)
#   adding: Surprise/35276.png (stored 0%)
#   adding: Surprise/32630.png (stored 0%)
#   adding: Surprise/33677.png (stored 0%)
#   adding: Surprise/35872.png (stored 0%)
#   adding: Surprise/34916.png (stored 0%)
#   adding: Surprise/34898.png (stored 0%)
#   adding: Surprise/33759.png (stored 0%)
#   adding: Surprise/34493.png (stored 0%)
#   adding: Surprise/33431.png (stored 0%)
#   adding: Surprise/35608.png (stored 0%)
#   adding: Surprise/33667.png (stored 0%)
#   adding: Surprise/33789.png (stored 0%)
#   adding: Surprise/32989.png (stored 0%)
#   adding: Surprise/35530.png (stored 0%)
#   adding: Surprise/35144.png (stored 0%)
#   adding: Surprise/35087.png (stored 0%)
#   adding: Surprise/33427.png (stored 0%)
#   adding: Surprise/33439.png (stored 0%)
#   adding: Surprise/33211.png (stored 0%)
#   adding: Surprise/34048.png (stored 0%)
#   adding: Surprise/33143.png (stored 0%)
#   adding: Surprise/32405.png (stored 0%)
#   adding: Surprise/32727.png (stored 0%)
#   adding: Surprise/33189.png (stored 0%)
#   adding: Surprise/35531.png (stored 0%)
#   adding: Surprise/33177.png (stored 0%)
#   adding: Surprise/32918.png (stored 0%)
#   adding: Surprise/34330.png (stored 0%)
#   adding: Surprise/33242.png (stored 0%)
#   adding: Surprise/34212.png (stored 0%)
#   adding: Surprise/34298.png (stored 0%)
#   adding: Surprise/35468.png (stored 0%)
#   adding: Surprise/34108.png (stored 0%)
#   adding: Surprise/32680.png (stored 0%)
#   adding: Surprise/35687.png (stored 0%)
#   adding: Surprise/34104.png (stored 0%)
#   adding: Surprise/32370.png (stored 0%)
#   adding: Surprise/33911.png (stored 0%)
#   adding: Surprise/33147.png (stored 0%)
#   adding: Surprise/35785.png (stored 0%)
#   adding: Surprise/33859.png (stored 0%)
#   adding: Surprise/33245.png (stored 0%)
#   adding: Surprise/32453.png (stored 0%)
#   adding: Surprise/32484.png (stored 0%)
#   adding: Surprise/32469.png (stored 0%)
#   adding: Surprise/32530.png (stored 0%)
#   adding: Surprise/34162.png (stored 0%)
#   adding: Surprise/35678.png (stored 0%)
#   adding: Surprise/32924.png (stored 0%)
#   adding: Surprise/32406.png (stored 0%)
#   adding: Surprise/34275.png (stored 0%)
#   adding: Surprise/33678.png (stored 0%)
#   adding: Surprise/35387.png (stored 0%)
#   adding: Surprise/33908.png (stored 0%)
#   adding: Surprise/34114.png (stored 0%)
#   adding: Surprise/34189.png (stored 0%)
#   adding: Surprise/33118.png (stored 0%)
#   adding: Surprise/34703.png (stored 0%)
#   adding: Surprise/34725.png (stored 0%)
#   adding: Surprise/35084.png (stored 0%)
#   adding: Surprise/35333.png (stored 0%)
#   adding: Surprise/34169.png (stored 0%)
#   adding: Surprise/35601.png (stored 0%)
#   adding: Surprise/33095.png (stored 0%)
#   adding: Surprise/33815.png (stored 0%)
#   adding: Surprise/35461.png (stored 0%)
#   adding: Surprise/33883.png (stored 0%)
#   adding: Surprise/35465.png (stored 0%)
#   adding: Surprise/33832.png (stored 0%)
#   adding: Surprise/35432.png (stored 0%)
#   adding: Surprise/32925.png (stored 0%)
#   adding: Surprise/35130.png (stored 0%)
#   adding: Surprise/33861.png (stored 0%)
#   adding: Surprise/33411.png (stored 0%)
#   adding: Surprise/32432.png (stored 0%)
#   adding: Surprise/32521.png (stored 0%)
#   adding: Surprise/33241.png (stored 0%)
#   adding: Surprise/34182.png (stored 0%)
#   adding: Surprise/35831.png (stored 0%)
#   adding: Surprise/33027.png (stored 0%)
#   adding: Surprise/35003.png (stored 0%)
#   adding: Surprise/32756.png (stored 0%)
#   adding: Surprise/33313.png (stored 0%)
#   adding: Surprise/34813.png (stored 0%)
#   adding: Surprise/35036.png (stored 0%)
#   adding: Surprise/33550.png (stored 0%)
#   adding: Surprise/32299.png (stored 0%)
#   adding: Surprise/33650.png (stored 0%)
#   adding: Surprise/33042.png (stored 0%)
#   adding: Surprise/33964.png (stored 0%)
#   adding: Surprise/32716.png (stored 0%)
#   adding: Surprise/35152.png (stored 0%)
#   adding: Surprise/34590.png (stored 0%)
#   adding: Surprise/32734.png (stored 0%)
#   adding: Surprise/35829.png (stored 0%)
#   adding: Surprise/34777.png (stored 0%)
#   adding: Surprise/34722.png (stored 0%)
#   adding: Surprise/32598.png (stored 0%)
#   adding: Surprise/32875.png (stored 0%)
#   adding: Surprise/32376.png (stored 0%)
#   adding: Surprise/34532.png (stored 0%)
#   adding: Surprise/34565.png (stored 0%)
#   adding: Surprise/32963.png (stored 0%)
#   adding: Surprise/35666.png (stored 0%)
#   adding: Surprise/32420.png (stored 0%)
#   adding: Surprise/34557.png (stored 0%)
#   adding: Surprise/34134.png (stored 0%)
#   adding: Surprise/33314.png (stored 0%)
#   adding: Surprise/33405.png (stored 0%)
#   adding: Surprise/33316.png (stored 0%)
#   adding: Surprise/33025.png (stored 0%)
#   adding: Surprise/33501.png (stored 0%)
#   adding: Surprise/33364.png (stored 0%)
#   adding: Surprise/33993.png (stored 0%)
#   adding: Surprise/32369.png (stored 0%)
#   adding: Surprise/35211.png (stored 0%)
#   adding: Surprise/33461.png (stored 0%)
#   adding: Surprise/33021.png (stored 0%)
#   adding: Surprise/33055.png (stored 0%)
#   adding: Surprise/34034.png (stored 0%)
#   adding: Surprise/34923.png (stored 0%)
#   adding: Surprise/33067.png (stored 0%)
#   adding: Surprise/33248.png (stored 0%)
#   adding: Surprise/35060.png (stored 0%)
#   adding: Surprise/32380.png (stored 0%)
#   adding: Surprise/33990.png (stored 0%)
#   adding: Surprise/35201.png (stored 0%)
#   adding: Surprise/32988.png (stored 0%)
#   adding: Surprise/35498.png (stored 0%)
#   adding: Surprise/33536.png (stored 0%)
#   adding: Surprise/33810.png (stored 0%)
#   adding: Surprise/34701.png (stored 0%)
#   adding: Surprise/33910.png (stored 0%)
#   adding: Surprise/32894.png (stored 0%)
#   adding: Surprise/35824.png (stored 0%)
#   adding: Surprise/34351.png (stored 0%)
#   adding: Surprise/35695.png (stored 0%)
#   adding: Surprise/33596.png (stored 0%)
#   adding: Surprise/32806.png (stored 0%)
#   adding: Surprise/34808.png (stored 0%)
#   adding: Surprise/32979.png (stored 0%)
#   adding: Surprise/32985.png (stored 0%)
#   adding: Surprise/34072.png (stored 0%)
#   adding: Surprise/34956.png (stored 0%)
#   adding: Surprise/35360.png (stored 0%)
#   adding: Surprise/35154.png (stored 0%)
#   adding: Surprise/34939.png (stored 0%)
#   adding: Surprise/35134.png (stored 0%)
#   adding: Surprise/34125.png (stored 0%)
#   adding: Surprise/34140.png (stored 0%)
#   adding: Surprise/35636.png (stored 0%)
#   adding: Surprise/33941.png (stored 0%)
#   adding: Surprise/34986.png (stored 0%)
#   adding: Surprise/33158.png (stored 0%)
#   adding: Surprise/34824.png (stored 0%)
#   adding: Surprise/33746.png (stored 0%)
#   adding: Surprise/34674.png (stored 0%)
#   adding: Surprise/35842.png (stored 0%)
#   adding: Surprise/35288.png (stored 0%)
#   adding: Surprise/35083.png (stored 0%)
#   adding: Surprise/33429.png (stored 0%)
#   adding: Surprise/34252.png (stored 0%)
#   adding: Surprise/34270.png (stored 0%)
#   adding: Surprise/32949.png (stored 0%)
#   adding: Surprise/35750.png (stored 0%)
#   adding: Surprise/33329.png (stored 0%)
#   adding: Surprise/34800.png (stored 0%)
#   adding: Surprise/32553.png (stored 0%)
#   adding: Surprise/35156.png (stored 0%)
#   adding: Surprise/35505.png (stored 0%)
#   adding: Surprise/34365.png (stored 0%)
#   adding: Surprise/32948.png (stored 0%)
#   adding: Surprise/33553.png (stored 0%)
#   adding: Surprise/33745.png (stored 0%)
#   adding: Surprise/33072.png (stored 0%)
#   adding: Surprise/34304.png (stored 0%)
#   adding: Surprise/35206.png (stored 0%)
#   adding: Surprise/35622.png (stored 0%)
#   adding: Surprise/34458.png (stored 0%)
#   adding: Surprise/34012.png (stored 0%)
#   adding: Surprise/34416.png (stored 0%)
#   adding: Surprise/35076.png (stored 0%)
#   adding: Surprise/34400.png (stored 0%)
#   adding: Surprise/32943.png (stored 0%)
#   adding: Surprise/34710.png (stored 0%)
#   adding: Surprise/33632.png (stored 0%)
#   adding: Surprise/32526.png (stored 0%)
#   adding: Surprise/34743.png (stored 0%)
#   adding: Surprise/33079.png (stored 0%)
#   adding: Surprise/35540.png (stored 0%)
#   adding: Surprise/34709.png (stored 0%)
#   adding: Surprise/34805.png (stored 0%)
#   adding: Surprise/32675.png (stored 0%)
#   adding: Surprise/34794.png (stored 0%)
#   adding: Surprise/34385.png (stored 0%)
#   adding: Surprise/33647.png (stored 0%)
#   adding: Surprise/35833.png (stored 0%)
#   adding: Surprise/32404.png (stored 0%)
#   adding: Surprise/34817.png (stored 0%)
#   adding: Surprise/35138.png (stored 0%)
#   adding: Surprise/34030.png (stored 0%)
#   adding: Surprise/32315.png (stored 0%)
#   adding: Surprise/33142.png (stored 0%)
#   adding: Surprise/35227.png (stored 0%)
#   adding: Surprise/35194.png (stored 0%)
#   adding: Surprise/35790.png (stored 0%)
#   adding: Surprise/35857.png (stored 0%)
#   adding: Surprise/34816.png (stored 0%)
#   adding: Surprise/35349.png (stored 0%)
#   adding: Surprise/32749.png (stored 0%)
#   adding: Surprise/34369.png (stored 0%)
#   adding: Surprise/34500.png (stored 0%)
#   adding: Surprise/35863.png (stored 0%)
#   adding: Surprise/33886.png (stored 0%)
#   adding: Surprise/35188.png (stored 0%)
#   adding: Surprise/32780.png (stored 0%)
#   adding: Surprise/35237.png (stored 0%)
#   adding: Surprise/35221.png (stored 0%)
#   adding: Surprise/32762.png (stored 0%)
#   adding: Surprise/35026.png (stored 0%)
#   adding: Surprise/35586.png (stored 0%)
#   adding: Surprise/32866.png (stored 0%)
#   adding: Surprise/35164.png (stored 0%)
#   adding: Surprise/32999.png (stored 0%)
#   adding: Surprise/34844.png (stored 0%)
#   adding: Surprise/35524.png (stored 0%)
#   adding: Surprise/35285.png (stored 0%)
#   adding: Surprise/32586.png (stored 0%)
#   adding: Surprise/34185.png (stored 0%)
#   adding: Surprise/32753.png (stored 0%)
#   adding: Surprise/32713.png (stored 0%)
#   adding: Surprise/33997.png (stored 0%)
#   adding: Surprise/34648.png (stored 0%)
#   adding: Surprise/34957.png (stored 0%)
#   adding: Surprise/35212.png (stored 0%)
#   adding: Surprise/34393.png (stored 0%)
#   adding: Surprise/33290.png (stored 0%)
#   adding: Surprise/32510.png (stored 0%)
#   adding: Surprise/33755.png (stored 0%)
#   adding: Surprise/34787.png (stored 0%)
#   adding: Surprise/33430.png (stored 0%)
#   adding: Surprise/34472.png (stored 0%)
#   adding: Surprise/33453.png (stored 0%)
#   adding: Surprise/35118.png (stored 0%)
#   adding: Surprise/35568.png (stored 0%)
#   adding: Surprise/32878.png (stored 0%)
#   adding: Surprise/33232.png (stored 0%)
#   adding: Surprise/34926.png (stored 0%)
#   adding: Surprise/34711.png (stored 0%)
#   adding: Surprise/33378.png (stored 0%)
#   adding: Surprise/34016.png (stored 0%)
#   adding: Surprise/35511.png (stored 0%)
#   adding: Surprise/33374.png (stored 0%)
#   adding: Surprise/35280.png (stored 0%)
#   adding: Surprise/35174.png (stored 0%)
#   adding: Surprise/34307.png (stored 0%)
#   adding: Surprise/34439.png (stored 0%)
#   adding: Surprise/33173.png (stored 0%)
#   adding: Surprise/35772.png (stored 0%)
#   adding: Surprise/33318.png (stored 0%)
#   adding: Surprise/34160.png (stored 0%)
#   adding: Surprise/35247.png (stored 0%)
#   adding: Surprise/32968.png (stored 0%)
#   adding: Surprise/32822.png (stored 0%)
#   adding: Surprise/34606.png (stored 0%)
#   adding: Surprise/35570.png (stored 0%)
#   adding: Surprise/35815.png (stored 0%)
#   adding: Surprise/33251.png (stored 0%)
#   adding: Surprise/34738.png (stored 0%)
#   adding: Surprise/34734.png (stored 0%)
#   adding: Surprise/32308.png (stored 0%)
#   adding: Surprise/35662.png (stored 0%)
#   adding: Surprise/32365.png (stored 0%)
#   adding: Surprise/34237.png (stored 0%)
#   adding: Surprise/34113.png (stored 0%)
#   adding: Surprise/33891.png (stored 0%)
#   adding: Surprise/33180.png (stored 0%)
#   adding: Surprise/32334.png (stored 0%)
#   adding: Surprise/32884.png (stored 0%)
#   adding: Surprise/32542.png (stored 0%)
#   adding: Surprise/34087.png (stored 0%)
#   adding: Surprise/35458.png (stored 0%)
#   adding: Surprise/33602.png (stored 0%)
#   adding: Surprise/33879.png (stored 0%)
#   adding: Surprise/34536.png (stored 0%)
#   adding: Surprise/33324.png (stored 0%)
#   adding: Surprise/33825.png (stored 0%)
#   adding: Surprise/33376.png (stored 0%)
#   adding: Surprise/35688.png (stored 0%)
#   adding: Surprise/35354.png (stored 0%)
#   adding: Surprise/33106.png (stored 0%)
#   adding: Surprise/34757.png (stored 0%)
#   adding: Surprise/34227.png (stored 0%)
#   adding: Surprise/33345.png (stored 0%)
#   adding: Surprise/34025.png (stored 0%)
#   adding: Surprise/33393.png (stored 0%)
#   adding: Surprise/35818.png (stored 0%)
#   adding: Surprise/33500.png (stored 0%)
#   adding: Surprise/34144.png (stored 0%)
#   adding: Surprise/32722.png (stored 0%)
#   adding: Surprise/35616.png (stored 0%)
#   adding: Surprise/32660.png (stored 0%)
#   adding: Surprise/35246.png (stored 0%)
#   adding: Surprise/32633.png (stored 0%)
#   adding: Surprise/35798.png (stored 0%)
#   adding: Surprise/34187.png (stored 0%)
#   adding: Surprise/33385.png (stored 0%)
#   adding: Surprise/33257.png (stored 0%)
#   adding: Surprise/32535.png (stored 0%)
#   adding: Surprise/33631.png (stored 0%)
#   adding: Surprise/34647.png (stored 0%)
#   adding: Surprise/35140.png (stored 0%)
#   adding: Surprise/34990.png (stored 0%)
#   adding: Surprise/35002.png (stored 0%)
#   adding: Surprise/34288.png (stored 0%)
#   adding: Surprise/33576.png (stored 0%)
#   adding: Surprise/33332.png (stored 0%)
#   adding: Surprise/35355.png (stored 0%)
#   adding: Surprise/35757.png (stored 0%)
#   adding: Surprise/32824.png (stored 0%)
#   adding: Surprise/35264.png (stored 0%)
#   adding: Surprise/32513.png (stored 0%)
#   adding: Surprise/35617.png (stored 0%)
#   adding: Surprise/33852.png (stored 0%)
#   adding: Surprise/34583.png (stored 0%)
#   adding: Surprise/35428.png (stored 0%)
#   adding: Surprise/33734.png (stored 0%)
#   adding: Surprise/33511.png (stored 0%)
#   adding: Surprise/35796.png (stored 0%)
#   adding: Surprise/32395.png (stored 0%)
#   adding: Surprise/32645.png (stored 0%)
#   adding: Surprise/34496.png (stored 0%)
#   adding: Surprise/34826.png (stored 0%)
#   adding: Surprise/35399.png (stored 0%)
#   adding: Surprise/35445.png (stored 0%)
#   adding: Surprise/35150.png (stored 0%)
#   adding: Surprise/33546.png (stored 0%)
#   adding: Surprise/32815.png (stored 0%)
#   adding: Surprise/35095.png (stored 0%)
#   adding: Surprise/35316.png (stored 0%)
#   adding: Surprise/33800.png (stored 0%)
#   adding: Surprise/32867.png (stored 0%)
#   adding: Surprise/34055.png (stored 0%)
#   adding: Surprise/33652.png (stored 0%)
#   adding: Surprise/32611.png (stored 0%)
#   adding: Surprise/34096.png (stored 0%)
#   adding: Surprise/35874.png (stored 0%)
#   adding: Surprise/33483.png (stored 0%)
#   adding: Surprise/33171.png (stored 0%)
#   adding: Surprise/32494.png (stored 0%)
#   adding: Surprise/35219.png (stored 0%)
#   adding: Surprise/34411.png (stored 0%)
#   adding: Surprise/35684.png (stored 0%)
#   adding: Surprise/34568.png (stored 0%)
#   adding: Surprise/35388.png (stored 0%)
#   adding: Surprise/34904.png (stored 0%)
#   adding: Surprise/33484.png (stored 0%)
#   adding: Surprise/33039.png (stored 0%)
#   adding: Surprise/35823.png (stored 0%)
# /content

# %%
# !ls
# Out:
# drive  PrivateTest  PublicTest	sample_data  Training

# %%
ls -l Training/
# Out:
# total 55344
# drwxr-xr-x 2 root root   131072 Oct 11 05:04 Angry/
# drwxr-xr-x 2 root root    16384 Oct 11 05:04 Disgust/
# drwxr-xr-x 2 root root   126976 Oct 11 05:04 Fear/
# drwxr-xr-x 2 root root   204800 Oct 11 05:04 Happy/
# drwxr-xr-x 2 root root   135168 Oct 11 05:04 Neutral/
# drwxr-xr-x 2 root root   135168 Oct 11 05:04 Sad/
# drwxr-xr-x 2 root root    81920 Oct 11 05:04 Surprise/
# -rw-r--r-- 1 root root 55812330 Oct 11 05:05 Training.zip

# %%
ls -l PublicTest/
# Out:
# total 6972
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Angry/
# drwxr-xr-x 2 root root    4096 Oct 11 05:04 Disgust/
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Fear/
# drwxr-xr-x 2 root root   36864 Oct 11 05:04 Happy/
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Neutral/
# -rw-r--r-- 1 root root 6992268 Oct 11 05:05 PublicTest.zip
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Sad/
# drwxr-xr-x 2 root root   16384 Oct 11 05:04 Surprise/

# %%
ls -l PrivateTest/
# Out:
# total 6964
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Angry/
# drwxr-xr-x 2 root root    4096 Oct 11 05:04 Disgust/
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Fear/
# drwxr-xr-x 2 root root   32768 Oct 11 05:04 Happy/
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Neutral/
# -rw-r--r-- 1 root root 6989840 Oct 11 05:05 PrivateTest.zip
# drwxr-xr-x 2 root root   20480 Oct 11 05:04 Sad/
# drwxr-xr-x 2 root root   16384 Oct 11 05:04 Surprise/

# %%
! ls {PrivateTest,PublicTest,Training}/*.zip
# Out:
# PrivateTest/PrivateTest.zip  PublicTest/PublicTest.zip	Training/Training.zip

# %%
# Copying all the zipped files to drive folder for permanently saving for later use.
# !cp {PrivateTest,PublicTest,Training}/*.zip '/content/drive/My Drive/ENGR635-Deep Learning System Design Project/Dataset/fer2013/'

# %%
# !ls '/content/drive/My Drive/ENGR635-Deep Learning System Design Project/Dataset/fer2013/'
# Out:
# fer2013.csv  PrivateTest.zip  PublicTest.zip  Training.zip
